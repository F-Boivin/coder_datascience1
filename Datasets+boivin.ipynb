# %% [markdown]
# <a href="https://colab.research.google.com/github/F-Boivin/coder_datascience1/blob/main/Datasets%2Bboivin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Bases de Python: Elección de Datasets
#
# Este notebook contiene el **primer avance del proyecto final**. El objetivo es identificar y documentar tres fuentes de datos que cumplan con los requisitos técnicos para un análisis posterior.
#
# ---
#
# ### 📝 Resumen de la Consigna
# Identificar **3 datasets potenciales** con las siguientes características mínimas:
# * **Filas:** $\geq 2000$
# * **Columnas:** $\geq 10$
#
# ---
#
# ## 🛠️ Tareas a Realizar
#
# 1.  **Búsqueda:** Seleccionar 3 datasets (GitHub, Kaggle, Google Dataset Search o archivos propios).
# 2.  **Hosting:** Subir los archivos a un repositorio de **GitHub**.
# 3.  **Carga de Datos:** Importar los datasets utilizando la librería `pandas`.
# 4.  **Análisis Preliminar:** Describir las variables más relevantes según el contexto comercial y analítico.
#
# ---
#
# ## 📋 Requisitos y Formato
#
# | Criterio | Detalle |
# | :--- | :--- |
# | **Repositorio** | Los datasets deben estar compartidos desde GitHub. |
# | **Código** | El notebook debe estar probado y ser funcional. |
# | **Formato de Entrega** | Archivo `.ipynb` |
# | **Nombre del Archivo** | `Datasets+Apellido.ipynb` |

# %%
import pandas as pd

# %% [markdown]
# # 1. Dataset: Impacto de la IA en el Rendimiento Estudiantil
#
# ### Contexto
# Este conjunto de datos explora cómo el uso de herramientas de Inteligencia Artificial (como ChatGPT o asistentes de código) influye en los resultados académicos de los estudiantes. Permite analizar los efectos de la tecnología en el desempeño del alumno.
#
# ### Variables de interés para el análisis:
# * **ai_usage_time_minutes (Tiempo de uso):** Permite ver si pasar más tiempo usando IA se traduce directamente en mejores notas o si hay un límite.
# * **ai_dependency_score (Nivel de dependencia):** Analiza la dependencia del alumno; qué tan "necesaria" siente que es la herramienta para su día a día.
# * **final_score (Nota final):** Es nuestra medida de éxito. Queremos ver cómo todas las demás variables terminan afectando este número.

# %%
# Dataset 1 - AI impact student performance
ai_impact_student_performance_dataset = pd.read_csv('https://raw.githubusercontent.com/F-Boivin/coder_datascience1/refs/heads/main/ai_impact_student_performance_dataset.csv')
ai_impact_student_performance_dataset.head()
# Out:
#    student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 0           1   20  Female    1st Year                  2.5        1
# 1           2   17    Male        12th                  3.4        1
# 2           3   24    Male    3rd Year                  0.8        0
# 3           4   21  Female        12th                  4.4        0
# 4           5   18   Other    3rd Year                  3.5        1
#
#    ai_usage_time_minutes   ai_tools_used ai_usage_purpose  \
# 0                    170             NaN        Exam Prep
# 1                    123             NaN            Notes
# 2                     35         Copilot    Doubt Solving
# 3                     45  ChatGPT+Gemini            Notes
# 4                     21  ChatGPT+Gemini           Coding
#
#    ai_dependency_score  ...  concept_understanding_score  \
# 0                   10  ...                            4
# 1                    4  ...                            8
# ...

# %% [markdown]
# # 2. Dataset: Campañas de Marketing Bancario
#
# ### Contexto
# Estos datos pertenecen a una institución bancaria de Portugal que realizó campañas de marketing directo (llamadas telefónicas) para que sus clientes contraten un depósito a plazo fijo. El objetivo analítico es descubrir qué características del cliente o de la llamada hacen que la persona acepte el producto.
#
# ### Variables de interés para el análisis:
# * **age (Edad):** Nos sirve para identificar a qué rango de edad le interesan más los productos de ahorro del banco.
# * **duration (Duración de la llamada):** Es un indicador clave de interés. Analíticamente, ayuda a entender cuánto tiempo debe durar una charla para ser efectiva.
# * **balance (Saldo en cuenta):** Nos permite saber si el nivel económico del cliente influye en su decisión de invertir en un depósito a plazo.
# * **y (Target):** Indica si el cliente contrató el producto. Es la variable más importante porque es el resultado final que queremos predecir.

# %%
# Dataset 2 - Bank marketing
bank_marketing = pd.read_csv('https://raw.githubusercontent.com/F-Boivin/coder_datascience1/refs/heads/main/bank.csv', sep=';')
bank_marketing.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# # 3. Dataset: Calidad del Vino Blanco
#
# ### Contexto
# Este dataset contiene mediciones químicas de casi 5.000 variantes de vino blanco. El objetivo es relacionar estas medidas objetivas (como el alcohol o la acidez) con la calificación de "calidad" que expertos humanos le dieron a cada vino. Es ideal para entender qué hace que un producto sea considerado de "alta gama".
#
# ### Variables de interés para el análisis:
# * **alcohol (Graduación alcohólica):** Es una de las variables que más suele influir en el puntaje de calidad que ponen los expertos.
# * **residual sugar (Azúcar residual):** Importante para clasificar los vinos según el gusto del consumidor (secos vs. dulces) y ver si influye en la nota final.
# * **quality (Calidad):** Es el puntaje del 1 al 10. Es la variable principal que queremos entender y predecir usando la química del vino.

# %%
# Dataset 3 - White whine quality
white_wine_quality = pd.read_csv('https://raw.githubusercontent.com/F-Boivin/coder_datascience1/refs/heads/main/winequalitywhite.csv')
white_wine_quality.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...
